# %% [markdown]
# <h1> Machine Learning Notebook

# %% [markdown]
# <h2> ToC

# %% [markdown]
# * [1. K-Means Analysis](#k_means)
# * [2. t-SNE Visualisation](#t_sne)
# * [3. DBScan](#dbscan)
# * [4. Cluster Characteristics](#characteristics)
# * [5. Etude de Sensibilité temporelle](#sensibilité)

# %%
import pandas as pd
import numpy as np
from random import sample
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
filepath = '/Users/efkanturedi/Corteze/Python_output_folders/Ecommerce/final_df.csv'
filepath2 = '/Users/efkanturedi/Corteze/Python_output_folders/Ecommerce/customer_df.csv'
filepath3 = '/Users/efkanturedi/Corteze/Python_output_folders/Ecommerce/master_df.csv'

df_original = pd.read_csv(filepath, parse_dates = True)
customer_df = pd.read_csv(filepath2,parse_dates = True)
master_df = pd.read_csv(filepath3)
# Out:
# /Users/efkanturedi/opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1,3,16,17,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_original
# Out:
#                      customer_unique_id customer_state  payment_value  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2             SP      -0.109922
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f             SP      -0.287416
# 2      0000f46a3911fa3c0805444483337064             SC      -0.196078
# 3      0000f6ccb0745a6a4b88665a16c9f078             PA      -0.261994
# 4      0004aac84e0df4da2b147fca70cf8255             SP      -0.024835
# ...                                 ...            ...            ...
# 93336  fffcf5a5ff07b0908bd4e2dbc735a684             PE       6.068458
# 93337  fffea47cd6d3cc0a88bd621562a9d061             BA      -0.198615
# 93338  ffff371b4d645b6ecea244b27531430a             MT      -0.155476
# 93339  ffff5962728ec6157033ef9805bacc48             ES      -0.122626
# 93340  ffffd2657e2aad2907e67c3e9daecbeb             PR      -0.218761
#
#       payment_type product_category_name  review_score  freight_value  \
# ...

# %%
master_df
# Out:
#                                 order_id payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                  1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                  1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                  1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                  1  credit_card
# 4       ba78997921bbcdc1373bb41e913ab953                  1  credit_card
# ...                                  ...                ...          ...
# 115709  c45067032fd84f4cf408730ff5205568                  1  credit_card
# 115710  0406037ad97740d563a178ecc7a2075c                  1       boleto
# 115711  7b905861d7c825891d6347454ea7863f                  1  credit_card
# 115712  b8b61059626efa996a60be9bb9320e10                  1  credit_card
# 115713  28bbae6599b09d39ca406b747b6632b1                  1       boleto
#
#        payment_installments  payment_value                       customer_id  \
# ...

# %%
n = len(df)
index_rand_selection = sample(list(range(0,n)),50000)

# %%
def datetimer(item):
    return pd.to_datetime(item)

# %%
df = df_original.iloc[index_rand_selection]
customer_df = customer_df.iloc[index_rand_selection]

# %%
df_clean = df.drop(columns=['customer_unique_id','customer_state','payment_type','product_category_name', 'order_purchase_date'])
df_clean.reset_index(inplace=True,drop=True)
customer_df.reset_index(inplace=True,drop=True)

# %%
df_clean
# Out:
#        payment_value  review_score  freight_value  geolocation_lat  \
# 0          -0.291764      0.665636      -0.635864        -0.397584
# 1          -0.218328     -0.108233      -0.198416        -0.200352
# 2          -0.218421      0.665636      -0.581320        -0.454293
# 3          -0.248749      0.665636      -0.277486         1.454233
# 4          -0.218730     -0.108233      -0.445510        -0.306878
# ...              ...           ...            ...              ...
# 49995      -0.088461      0.665636       0.439635        -0.352041
# 49996       0.093984     -0.495167       0.729193        -0.601426
# 49997      -0.124127     -0.108233      -0.257718        -0.278588
# 49998      -0.209462     -0.108233      -0.259549         0.809568
# 49999      -0.196186      0.665636      -0.311530        -1.574507
#
#        geolocation_lng  pca_comp0  pca_comp1  pca_comp2  pca_comp3  pca_comp4  \
# 0            -0.048966  -0.034814  -0.081859  -0.083444  -0.029173  -0.085498
# ...

# %%
customer_df
# Out:
#                      customer_unique_id customer_state  payment_value  \
# 0      659772479699169589989ac0897fd1fa             SP          24.38
# 1      14dc38f61b67d510ecd9b9e5c031cbc8             SP          71.84
# 2      7fb1599a88a6b7d15f100b29908d25bd             SP          71.78
# 3      48e4b7f31748195c4df64113e2fa7330             BA          52.18
# 4      047da58c84a4e46b1e22557054715b6c             RJ          71.58
# ...                                 ...            ...            ...
# 49995  625ce1a10005bd1238f9a2ec9fb1c3c0             SP         155.77
# 49996  1912afd96bbe171633bb73727487ef85             PR         273.68
# 49997  475b371565fac3dde82974b8c43b89ed             SP         132.72
# 49998  27aacd37c12bc685a275af86f14d2c23             GO          77.57
# 49999  42f296ed9782627fc7408a950975cfd2             RS          86.15
#
#       payment_type product_category_name  review_score  freight_value  \
# ...

# %% [markdown]
# <h2> K-means Analysis
#     <a name = 'k_means'>

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(3,15),metric='silhouette')

visualizer.fit(df_clean)    # Fit the data to the visualizer
visualizer.poof()    # Draw/show/poof the data
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
visualizer = KElbowVisualizer(model, k=(3,15))
visualizer.fit(df_clean)    # Fit the data to the visualizer
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
optimal_parameter = 8

model = KMeans(optimal_parameter)
visualizer = SilhouetteVisualizer(model)

visualizer.fit(df_clean)    # Fit the data to the visualizer
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 50000 Samples in 8 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# <h2> K-Means / T-SNE Visualisation
#     <a name = 't_sne'>

# %%
from sklearn.manifold import TSNE

# %%
k_means = KMeans(optimal_parameter)
k_means.fit(df_clean.copy())
clusters_k_means = k_means.labels_

# %%
#tsne = TSNE()
#T = tsne.fit_transform(df_clean.copy())

# %%
#plt.figure(figsize=(8,8))
#plt.title('Représentation du jeu de données via T-SNE')
#sns.scatterplot(T[:,0], T[:,1],hue=clusters_k_means,legend='full',palette="hls")

# %% [markdown]
# <h2> DBSCAN: Not working well
#     <a name = 'dbscan'>

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

# %%
dbs = DBSCAN(eps = 1, 
             min_samples=5).fit(df_clean.copy())

# %%
dbs.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
silhouette_score(df_clean,dbs.labels_)
# Out:
# 0.2741715102195324

# %%
from collections import Counter

Counter(dbs.labels_)
# Out:
# Counter({0: 48162,
#          -1: 1730,
#          1: 53,
#          7: 7,
#          2: 14,
#          6: 5,
#          3: 5,
#          4: 6,
#          9: 4,
#          5: 10,
#          8: 4})

# %%
tsne = TSNE()
T = tsne.fit_transform(df_clean.copy())

# %%
plt.figure(figsize=(8,8))
plt.title('Représentation du jeu de données via T-SNE')
sns.scatterplot(T[:,0], T[:,1],hue=dbs.labels_,legend='full',palette="hls")
# Out:
# /Users/efkanturedi/opt/anaconda3/envs/py39/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Représentation du jeu de données via T-SNE'}>

# %%
cat_df_clean = df_clean.assign(Cluster=dbs.labels_)

# %%
cat_df_clean['Cluster'].value_counts().sort_values()
# Out:
#  8        4
#  9        4
#  3        5
#  6        5
#  4        6
#  7        7
#  5       10
#  2       14
#  1       53
# -1     1730
#  0    48162
# Name: Cluster, dtype: int64

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#                      customer_unique_id customer_state  payment_value  \
# 0      659772479699169589989ac0897fd1fa             SP      -0.291764
# 1      14dc38f61b67d510ecd9b9e5c031cbc8             SP      -0.218328
# 2      7fb1599a88a6b7d15f100b29908d25bd             SP      -0.218421
# 3      48e4b7f31748195c4df64113e2fa7330             BA      -0.248749
# 4      047da58c84a4e46b1e22557054715b6c             RJ      -0.218730
# ...                                 ...            ...            ...
# 49995  625ce1a10005bd1238f9a2ec9fb1c3c0             SP      -0.088461
# 49996  1912afd96bbe171633bb73727487ef85             PR       0.093984
# 49997  475b371565fac3dde82974b8c43b89ed             SP      -0.124127
# 49998  27aacd37c12bc685a275af86f14d2c23             GO      -0.209462
# 49999  42f296ed9782627fc7408a950975cfd2             RS      -0.196186
#
#       payment_type product_category_name  review_score  freight_value  \
# ...

# %%
customer_df = customer_df.assign(Cluster_k_means=k_means.labels_,Cluster_DBS=dbs.labels_)
customer_df
# Out:
#                      customer_unique_id customer_state  payment_value  \
# 0      659772479699169589989ac0897fd1fa             SP          24.38
# 1      14dc38f61b67d510ecd9b9e5c031cbc8             SP          71.84
# 2      7fb1599a88a6b7d15f100b29908d25bd             SP          71.78
# 3      48e4b7f31748195c4df64113e2fa7330             BA          52.18
# 4      047da58c84a4e46b1e22557054715b6c             RJ          71.58
# ...                                 ...            ...            ...
# 49995  625ce1a10005bd1238f9a2ec9fb1c3c0             SP         155.77
# 49996  1912afd96bbe171633bb73727487ef85             PR         273.68
# 49997  475b371565fac3dde82974b8c43b89ed             SP         132.72
# 49998  27aacd37c12bc685a275af86f14d2c23             GO          77.57
# 49999  42f296ed9782627fc7408a950975cfd2             RS          86.15
#
#       payment_type product_category_name  review_score  freight_value  \
# ...

# %% [markdown]
# <h2> Cluster characteristics
#     <a name = 'characteristics'>

# %%
clustered_cust_df = customer_df.groupby('Cluster_k_means')
clustered_cust_df.agg({
    'customer_unique_id': 'count',
    'payment_value':'mean',
    'review_score' :'mean',
    'freight_value' :'mean',
    'geolocation_lat' :'mean',
    'geolocation_lng' :'mean',
  })
# Out:
#                  customer_unique_id  payment_value  review_score  \
# Cluster_k_means
# 0                              4356     207.049210      3.986892
# 1                              7484     169.220285      4.639248
# 2                              8265     195.080218      1.856375
# 3                                 1  109312.640000      1.000000
# 4                              1153    1495.053547      3.723180
# 5                              3137     189.139015      4.399479
# 6                                36   11999.387778      2.621296
# 7                             25568     157.640186      4.755551
#
#                  freight_value  geolocation_lat  geolocation_lng
# Cluster_k_means
# 0                    33.738127        -8.724461       -38.432783
# 1                    22.651539       -26.273915       -51.015082
# 2                    22.064491       -22.721210       -46.153121
# 3                   224.080000       -22.900792       -43.185126
# ...

# %% [markdown]
# <h2> Etude de sensibilité temporelle
#     <a name = 'sensibilité'>

# %% [markdown]
# Retirer les clients ayant fait des achats dans les N derniers mois, pour voir si le clustering evolue. On va regarder des pas de 3 et 6 mois. Notre cluster du dessus sera considéré comme étant le cluster initial. On utilisera la fonction adjusted Rand Index pour évaluer la similitude des clustering.

# %% [markdown]
# Quel est l'achat le plus récent?

# %%
master_df.dtypes
# Out:
# order_id                          object
# payment_sequential                object
# payment_type                      object
# payment_installments              object
# payment_value                    float64
# customer_id                       object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# order_item_id                    float64
# product_id                        object
# seller_id                         object
# shipping_limit_date               object
# price                             object
# freight_value                     object
# review_id                         object
# review_score                     float64
# review_comment_title              object
# review_comment_message            object
# review_creation_date              object
# ...

# %%
cols_of_interest = ['customer_unique_id', 'customer_state','payment_value','payment_type', 'product_category_name', 'review_score', 'freight_value', 'geolocation_lat', 'geolocation_lng','order_purchase_date']
master_df = master_df[cols_of_interest]

# %%
master_df
# Out:
#                       customer_unique_id customer_state  payment_value  \
# 0       708ab75d2a007f0564aedd11139c7708             MG          99.33
# 1       a8b9d3a27068454b1c98cc67d4e31e6f             SP          24.39
# 2       6f70c0b2f7552832ba46eb57b1c5651e             SP          65.71
# 3       87695ed086ebd36f20404c82d20fca87             MG         107.78
# 4       87695ed086ebd36f20404c82d20fca87             MG         107.78
# ...                                  ...            ...            ...
# 115709  13f283df2f4760f22b57830865761d07             PR         198.94
# 115710  b6027ac07fb76ebca8c97b1887865aee             SP         363.31
# 115711  53b30ca78efb2b7efcd3f9e461587eb2             MG          96.80
# 115712  b84dc68f02f122a88d7e7bbd37b06204             RJ         369.54
# 115713  b1f51a4e19da3338e51fbcfabefad1bf             RJ         191.58
#
#        payment_type      product_category_name  review_score freight_value  \
# ...

# %%
master_df['payment_value'] = pd.to_numeric(master_df['payment_value'], downcast="float")
master_df['review_score'] = pd.to_numeric(master_df['review_score'], downcast="float")
master_df['freight_value'] = pd.to_numeric(master_df['freight_value'], downcast="float")
master_df['geolocation_lat'] = pd.to_numeric(master_df['geolocation_lat'], downcast="float")
master_df['geolocation_lng'] = pd.to_numeric(master_df['geolocation_lng'], downcast="float")
master_df['order_purchase_date'] = pd.to_datetime(master_df['order_purchase_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "SP"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-f432dcf2e9d2> in <module>
#       1 master_df['payment_value'] = pd.to_numeric(master_df['payment_value'], downcast="float")
#       2 master_df['review_score'] = pd.to_numeric(master_df['review_score'], downcast="float")
# ----> 3 master_df['freight_value'] = pd.to_numeric(master_df['freight_value'], downcast="float")
#       4 master_df['geolocation_lat'] = pd.to_numeric(master_df['geolocation_lat'], downcast="float")
#       5 master_df['geolocation_lng'] = pd.to_numeric(master_df['geolocation_lng'], downcast="float")
#
# ...

# %%
master_df = master_df.dropna(how='any')

# %%
master_df[master_df['price']=='valinhos']
# Out:
#       order_id   payment_sequential         payment_type  \
# 41892      NaN  2017-09-09 00:00:00  2017-09-11 01:28:36
# 41894      NaN  2017-09-09 00:00:00  2017-09-11 01:28:36
#
#                    payment_installments  payment_value  customer_id  \
# 41892  2bb9fa7ec912785d8e0c8643e67a9e9e        35500.0  divinopolis
# 41894  2bb9fa7ec912785d8e0c8643e67a9e9e        35500.0  divinopolis
#
#       order_status order_purchase_timestamp order_approved_at  \
# 41892           MG                perfumery              58.0
# 41894           MG                perfumery              58.0
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 41892                        560.0                           1.0
# 41894                        560.0                           1.0
#
#       order_estimated_delivery_date  order_item_id product_id seller_id  \
# 41892                         650.0           20.0        8.0      20.0
# ...

# %%
master_df
# Out:
#                                 order_id payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                  1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                  1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                  1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                  1  credit_card
# 4       ba78997921bbcdc1373bb41e913ab953                  1  credit_card
# ...                                  ...                ...          ...
# 115709  c45067032fd84f4cf408730ff5205568                  1  credit_card
# 115710  0406037ad97740d563a178ecc7a2075c                  1       boleto
# 115711  7b905861d7c825891d6347454ea7863f                  1  credit_card
# 115712  b8b61059626efa996a60be9bb9320e10                  1  credit_card
# 115713  28bbae6599b09d39ca406b747b6632b1                  1       boleto
#
#        payment_installments  payment_value                       customer_id  \
# ...

# %%
most_frequent = lambda x:x.mode()[0]
lister = lambda x:list(set(x))
lister_2 = lambda x:list(x)
lister_3 = lambda x:max(list(set(pd.to_datetime(x))))

# %%
master_df['price'] = pd.to_numeric(master_df['price'], downcast="float")

# %%
# Out:
# numpy.float32

# %%
idx=[]
for i in range(len(master_df)):
    if type(master_df['price'].iloc[i]) is not float:
        idx.append(i)

# %%
customer_df_new = master_df.groupby([
  'customer_unique_id',
  'customer_state',
], as_index=False).agg({
  'payment_value': 'sum',
  'payment_type' : most_frequent,
  'product_category_name' : lister,
  'review_score': 'mean',
  'freight_value':'sum',
  'geolocation_lat':'mean',
  'geolocation_lng':'mean',
  'order_purchase_date': lister_3
})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-d3fc33bdcd7a> in <module>
# ----> 1 customer_df_new = master_df.groupby([
#       2   'customer_unique_id',
#       3   'customer_state',
#       4 ], as_index=False).agg({
#       5   'payment_value': 'sum',
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     580     elif is_dict_like(arg):
#     581         arg = cast(AggFuncTypeDict, arg)
# ...
